# %%
import pandas as pd

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  15.0  1.0  0.0   0.0
# 1  Leicester City  ...  Match Report    NaN  19.0  7.0  12.6  0.0  0.0   0.0
# 2     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.6  0.0  0.0   0.0
# 3          Fulham  ...  Match Report    NaN  23.0  8.0  16.6  1.0  0.0   0.0
# 4     Aston Villa  ...  Match Report    NaN  22.0  8.0  15.3  1.0  0.0   0.0
#
#    season     team
# 0    2022  Arsenal
# 1    2022  Arsenal
# 2    2022  Arsenal
# 3    2022  Arsenal
# 4    2022  Arsenal
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (936, 27)

# %%
matches.team.value_counts()
# Out:
# Brentford                   48
# Wolverhampton Wanderers     47
# Newcastle United            47
# West Ham United             47
# Southampton                 47
# Everton                     47
# Manchester City             47
# Brighton and Hove Albion    47
# Leicester City              47
# Tottenham Hotspur           47
# Arsenal                     47
# Aston Villa                 47
# Manchester United           46
# Leeds United                46
# Chelsea                     46
# Crystal Palace              46
# Liverpool                   46
# Norwich City                38
# Burnley                     38
# Watford                     38
# Nottingham Forest            9
# Bournemouth                  9
# Fulham                       9
# Name: team, dtype: int64

# %%
matches[matches['team'] == 'Liverpool']
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Away      D  2.0
# 2   2022-08-15  20:00  Premier League   Matchweek 2  Mon  Home      D  1.0
# 3   2022-08-22  20:00  Premier League   Matchweek 3  Mon  Away      L  1.0
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  9.0
# 5   2022-08-31  20:00  Premier League   Matchweek 5  Wed  Home      W  2.0
# 6   2022-09-03  12:30  Premier League   Matchweek 6  Sat  Away      D  0.0
# 9   2022-10-01  15:00  Premier League   Matchweek 9  Sat  Home      D  3.0
# 11  2022-10-09  16:30  Premier League  Matchweek 10  Sun  Away      L  2.0
# 0   2021-08-14  17:30  Premier League   Matchweek 1  Sat  Away      W  3.0
# 1   2021-08-21  12:30  Premier League   Matchweek 2  Sat  Home      W  2.0
# 2   2021-08-28  17:30  Premier League   Matchweek 3  Sat  Home      D  1.0
# 3   2021-09-12  16:30  Premier League   Matchweek 4  Sun  Away      W  3.0
# 5   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# 7   2021-09-25  17:30  Premier League   Matchweek 6  Sat  Away      D  3.0
# 9   2021-10-03  16:30  Premier League   Matchweek 7  Sun  Home      D  2.0
# 10  2021-10-16  12:30  Premier League   Matchweek 8  Sat  Away      W  5.0
# 12  2021-10-24  16:30  Premier League   Matchweek 9  Sun  Away      W  5.0
# 14  2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      D  2.0
# 16  2021-11-07  16:30  Premier League  Matchweek 11  Sun  Away      L  2.0
# 17  2021-11-20  17:30  Premier League  Matchweek 12  Sat  Home      W  4.0
# 19  2021-11-27  15:00  Premier League  Matchweek 13  Sat  Home      W  4.0
# 20  2021-12-01  20:15  Premier League  Matchweek 14  Wed  Away      W  4.0
# 21  2021-12-04  15:00  Premier League  Matchweek 15  Sat  Away      W  1.0
# 23  2021-12-11  15:00  Premier League  Matchweek 16  Sat  Home      W  1.0
# 24  2021-12-16  20:00  Premier League  Matchweek 17  Thu  Home      W  3.0
# 25  2021-12-19  16:30  Premier League  Matchweek 18  Sun  Away      D  2.0
# 27  2021-12-28  20:00  Premier League  Matchweek 20  Tue  Away      L  0.0
# 28  2022-01-02  16:30  Premier League  Matchweek 21  Sun  Away      D  2.0
# 31  2022-01-16  14:00  Premier League  Matchweek 22  Sun  Home      W  3.0
# 33  2022-01-23  14:00  Premier League  Matchweek 23  Sun  Away      W  3.0
# 35  2022-02-10  19:45  Premier League  Matchweek 24  Thu  Home      W  2.0
# 36  2022-02-13  14:00  Premier League  Matchweek 25  Sun  Away      W  1.0
# 38  2022-02-19  15:00  Premier League  Matchweek 26  Sat  Home      W  3.0
# 39  2022-02-23  19:45  Premier League  Matchweek 19  Wed  Home      W  6.0
# 42  2022-03-05  17:30  Premier League  Matchweek 28  Sat  Home      W  1.0
# 44  2022-03-12  12:30  Premier League  Matchweek 29  Sat  Away      W  2.0
# 45  2022-03-16  20:15  Premier League  Matchweek 27  Wed  Away      W  2.0
# 47  2022-04-02  12:30  Premier League  Matchweek 31  Sat  Home      W  2.0
# 49  2022-04-10  16:30  Premier League  Matchweek 32  Sun  Away      D  2.0
# 52  2022-04-19  20:00  Premier League  Matchweek 30  Tue  Home      W  4.0
# 53  2022-04-24  16:30  Premier League  Matchweek 34  Sun  Home      W  2.0
# 55  2022-04-30  12:30  Premier League  Matchweek 35  Sat  Away      W  1.0
# 57  2022-05-07  19:45  Premier League  Matchweek 36  Sat  Home      D  1.0
# 58  2022-05-10  20:00  Premier League  Matchweek 33  Tue  Away      W  2.0
# 60  2022-05-17  19:45  Premier League  Matchweek 37  Tue  Away      W  2.0
# 61  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W  3.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk  \
# 1   2.0           Fulham  ...  Match Report    NaN  11.0   3.0  11.8  0.0
# 2   1.0   Crystal Palace  ...  Match Report    NaN  24.0   4.0  17.1  0.0
# 3   2.0   Manchester Utd  ...  Match Report    NaN  17.0   5.0  14.5  0.0
# 4   0.0      Bournemouth  ...  Match Report    NaN  19.0  12.0  10.8  0.0
# 5   1.0    Newcastle Utd  ...  Match Report    NaN  23.0   6.0  17.4  0.0
# 6   0.0          Everton  ...  Match Report    NaN  24.0   9.0  12.3  0.0
# 9   3.0         Brighton  ...  Match Report    NaN  15.0   7.0  16.0  1.0
# 11  3.0          Arsenal  ...  Match Report    NaN   8.0   3.0  17.1  0.0
# 0   0.0     Norwich City  ...  Match Report    NaN  19.0   6.0  16.4  1.0
# 1   0.0          Burnley  ...  Match Report    NaN  28.0   8.0  15.1  0.0
# 2   1.0          Chelsea  ...  Match Report    NaN  23.0   6.0  14.8  0.0
# 3   0.0     Leeds United  ...  Match Report    NaN  30.0   8.0  14.7  1.0
# 5   0.0   Crystal Palace  ...  Match Report    NaN  25.0  10.0  15.2  0.0
# 7   3.0        Brentford  ...  Match Report    NaN  15.0   4.0  16.2  1.0
# 9   2.0  Manchester City  ...  Match Report    NaN   6.0   3.0  15.2  1.0
# 10  0.0          Watford  ...  Match Report    NaN  19.0   8.0  15.5  0.0
# 12  0.0   Manchester Utd  ...  Match Report    NaN  19.0   8.0  16.0  0.0
# 14  2.0         Brighton  ...  Match Report    NaN  14.0   3.0  19.7  0.0
# 16  3.0         West Ham  ...  Match Report    NaN  16.0   5.0  15.8  0.0
# 17  0.0          Arsenal  ...  Match Report    NaN  19.0   9.0  12.6  0.0
# 19  0.0      Southampton  ...  Match Report    NaN  20.0   6.0  15.3  0.0
# 20  1.0          Everton  ...  Match Report    NaN  16.0   7.0  15.6  1.0
# 21  0.0           Wolves  ...  Match Report    NaN  17.0   4.0  12.8  0.0
# 23  0.0      Aston Villa  ...  Match Report    NaN  20.0   4.0  14.5  0.0
# 24  1.0    Newcastle Utd  ...  Match Report    NaN  23.0   8.0  15.3  0.0
# 25  2.0        Tottenham  ...  Match Report    NaN  18.0   6.0  16.1  0.0
# 27  1.0   Leicester City  ...  Match Report    NaN  20.0   3.0  13.6  0.0
# 28  2.0          Chelsea  ...  Match Report    NaN  10.0   5.0  17.2  0.0
# 31  0.0        Brentford  ...  Match Report    NaN  27.0  13.0  15.9  0.0
# 33  1.0   Crystal Palace  ...  Match Report    NaN  13.0   6.0  21.8  0.0
# 35  0.0   Leicester City  ...  Match Report    NaN  22.0  12.0  14.7  0.0
# 36  0.0          Burnley  ...  Match Report    NaN  12.0   4.0  14.0  0.0
# 38  1.0     Norwich City  ...  Match Report    NaN  29.0   7.0  17.4  0.0
# 39  0.0     Leeds United  ...  Match Report    NaN  21.0  12.0  17.2  0.0
# 42  0.0         West Ham  ...  Match Report    NaN  22.0   5.0  18.0  0.0
# 44  0.0         Brighton  ...  Match Report    NaN  17.0   8.0  15.0  0.0
# 45  0.0          Arsenal  ...  Match Report    NaN   9.0   3.0  13.7  0.0
# 47  0.0          Watford  ...  Match Report    NaN  19.0   2.0  18.4  0.0
# 49  2.0  Manchester City  ...  Match Report    NaN   6.0   4.0  23.5  0.0
# 52  0.0   Manchester Utd  ...  Match Report    NaN  14.0   5.0  14.8  0.0
# 53  0.0          Everton  ...  Match Report    NaN  18.0   4.0  15.1  0.0
# 55  0.0    Newcastle Utd  ...  Match Report    NaN  24.0  11.0  17.4  2.0
# 57  1.0        Tottenham  ...  Match Report    NaN  22.0   3.0  18.6  0.0
# 58  1.0      Aston Villa  ...  Match Report    NaN  17.0   5.0  15.4  2.0
# 60  1.0      Southampton  ...  Match Report    NaN  24.0   5.0  17.5  0.0
# 61  1.0           Wolves  ...  Match Report    NaN  29.0   7.0  15.2  0.0
#
#      pk pkatt  season       team
# 1   0.0   0.0    2022  Liverpool
# 2   0.0   0.0    2022  Liverpool
# 3   0.0   0.0    2022  Liverpool
# 4   0.0   0.0    2022  Liverpool
# 5   0.0   0.0    2022  Liverpool
# 6   0.0   0.0    2022  Liverpool
# 9   0.0   0.0    2022  Liverpool
# 11  0.0   0.0    2022  Liverpool
# 0   0.0   0.0    2021  Liverpool
# 1   0.0   0.0    2021  Liverpool
# 2   1.0   1.0    2021  Liverpool
# 3   0.0   0.0    2021  Liverpool
# 5   0.0   0.0    2021  Liverpool
# 7   0.0   0.0    2021  Liverpool
# 9   0.0   0.0    2021  Liverpool
# 10  0.0   0.0    2021  Liverpool
# 12  0.0   0.0    2021  Liverpool
# 14  0.0   0.0    2021  Liverpool
# 16  0.0   0.0    2021  Liverpool
# 17  0.0   0.0    2021  Liverpool
# 19  0.0   0.0    2021  Liverpool
# 20  0.0   0.0    2021  Liverpool
# 21  0.0   0.0    2021  Liverpool
# 23  1.0   1.0    2021  Liverpool
# 24  0.0   0.0    2021  Liverpool
# 25  0.0   0.0    2021  Liverpool
# 27  0.0   1.0    2021  Liverpool
# 28  0.0   0.0    2021  Liverpool
# 31  0.0   0.0    2021  Liverpool
# 33  1.0   1.0    2021  Liverpool
# 35  0.0   0.0    2021  Liverpool
# 36  0.0   0.0    2021  Liverpool
# 38  0.0   0.0    2021  Liverpool
# 39  2.0   2.0    2021  Liverpool
# 42  0.0   0.0    2021  Liverpool
# 44  1.0   1.0    2021  Liverpool
# 45  0.0   0.0    2021  Liverpool
# 47  1.0   1.0    2021  Liverpool
# 49  0.0   0.0    2021  Liverpool
# 52  0.0   0.0    2021  Liverpool
# 53  0.0   0.0    2021  Liverpool
# 55  0.0   0.0    2021  Liverpool
# 57  0.0   0.0    2021  Liverpool
# 58  0.0   0.0    2021  Liverpool
# 60  0.0   0.0    2021  Liverpool
# 61  0.0   0.0    2021  Liverpool
#
# [46 rows x 27 columns]

# %%
matches['round'].value_counts()
# Out:
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 4     40
# Matchweek 3     40
# Matchweek 5     40
# Matchweek 2     40
# Matchweek 6     40
# Matchweek 1     40
# Matchweek 8     34
# Matchweek 11    22
# Matchweek 20    20
# Matchweek 26    20
# Matchweek 30    20
# Matchweek 22    20
# Matchweek 29    20
# Matchweek 16    20
# Matchweek 37    20
# Matchweek 36    20
# Matchweek 24    20
# Matchweek 27    20
# Matchweek 34    20
# Matchweek 25    20
# Matchweek 33    20
# Matchweek 31    20
# Matchweek 35    20
# Matchweek 28    20
# Matchweek 17    20
# Matchweek 13    20
# Matchweek 32    20
# Matchweek 14    20
# Matchweek 19    20
# Matchweek 15    20
# Matchweek 23    20
# Matchweek 18    20
# Matchweek 7     20
# Matchweek 38    20
# Matchweek 12    20
# Matchweek 21    20
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches['date'] = pd.to_datetime(matches['date'])

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga        opponent  ...  match report  notes    sh  sot  dist   fk   pk  \
# 0   0.0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  15.0  1.0  0.0
# 1   2.0  Leicester City  ...  Match Report    NaN  19.0  7.0  12.6  0.0  0.0
# 2   0.0     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.6  0.0  0.0
# 3   1.0          Fulham  ...  Match Report    NaN  23.0  8.0  16.6  1.0  0.0
# 4   1.0     Aston Villa  ...  Match Report    NaN  22.0  8.0  15.3  1.0  0.0
# ..  ...             ...  ...           ...    ...   ...  ...   ...  ...  ...
# 38  2.0     Aston Villa  ...  Match Report    NaN  10.0  3.0  20.7  0.0  0.0
# 39  4.0        West Ham  ...  Match Report    NaN   8.0  2.0  21.5  1.0  0.0
# 40  3.0  Leicester City  ...  Match Report    NaN   9.0  5.0  16.2  0.0  0.0
# 41  1.0          Wolves  ...  Match Report    NaN  11.0  2.0  13.4  0.0  0.0
# 42  5.0       Tottenham  ...  Match Report    NaN   9.0  0.0  17.1  0.0  0.0
#
#    pkatt  season          team
# 0    0.0    2022       Arsenal
# 1    0.0    2022       Arsenal
# 2    0.0    2022       Arsenal
# 3    0.0    2022       Arsenal
# 4    0.0    2022       Arsenal
# ..   ...     ...           ...
# 38   0.0    2021  Norwich City
# 39   0.0    2021  Norwich City
# 40   0.0    2021  Norwich City
# 41   0.0    2021  Norwich City
# 42   0.0    2021  Norwich City
#
# [936 rows x 27 columns]

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
matches['venue_code'] = matches['venue'].astype('category').cat.codes

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga        opponent  ...  notes    sh  sot  dist   fk   pk pkatt season  \
# 0   0.0  Crystal Palace  ...    NaN  10.0  2.0  15.0  1.0  0.0   0.0   2022
# 1   2.0  Leicester City  ...    NaN  19.0  7.0  12.6  0.0  0.0   0.0   2022
# 2   0.0     Bournemouth  ...    NaN  14.0  6.0  14.6  0.0  0.0   0.0   2022
# 3   1.0          Fulham  ...    NaN  23.0  8.0  16.6  1.0  0.0   0.0   2022
# 4   1.0     Aston Villa  ...    NaN  22.0  8.0  15.3  1.0  0.0   0.0   2022
# ..  ...             ...  ...    ...   ...  ...   ...  ...  ...   ...    ...
# 38  2.0     Aston Villa  ...    NaN  10.0  3.0  20.7  0.0  0.0   0.0   2021
# 39  4.0        West Ham  ...    NaN   8.0  2.0  21.5  1.0  0.0   0.0   2021
# 40  3.0  Leicester City  ...    NaN   9.0  5.0  16.2  0.0  0.0   0.0   2021
# 41  1.0          Wolves  ...    NaN  11.0  2.0  13.4  0.0  0.0   0.0   2021
# 42  5.0       Tottenham  ...    NaN   9.0  0.0  17.1  0.0  0.0   0.0   2021
#
#             team  venue_code
# 0        Arsenal           0
# 1        Arsenal           1
# 2        Arsenal           0
# 3        Arsenal           1
# 4        Arsenal           1
# ..           ...         ...
# 38  Norwich City           0
# 39  Norwich City           1
# 40  Norwich City           0
# 41  Norwich City           0
# 42  Norwich City           1
#
# [936 rows x 28 columns]

# %%
matches['opp_code'] = matches['opponent'].astype('category').cat.codes

# %%
matches['hour'] = matches['time'].str.replace(':.+', '', regex=True).astype('int')

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2 2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3 2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...   fk   pk  pkatt  season     team venue_code opp_code  \
# 0  Crystal Palace  ...  1.0  0.0    0.0    2022  Arsenal          0        7
# 1  Leicester City  ...  0.0  0.0    0.0    2022  Arsenal          1       11
# 2     Bournemouth  ...  0.0  0.0    0.0    2022  Arsenal          0        2
# 3          Fulham  ...  1.0  0.0    0.0    2022  Arsenal          1        9
# 4     Aston Villa  ...  1.0  0.0    0.0    2022  Arsenal          1        1
#
#   hour  day_code  target
# 0   20         4       1
# 1   15         5       1
# 2   17         5       1
# 3   17         5       1
# 4   19         2       1
#
# [5 rows x 32 columns]

# %%
matches['day_code'] = matches['date'].dt.dayofweek

# %%
matches['target'] = (matches['result'] == 'W').astype('int')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches['date'] < '2022-01-01']

# %%
test = matches[matches['date'] > '2022-01-01']

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test['target'], preds)

# %%
acc
# Out:
# 0.5939716312056738

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           266  78
# 1           151  69

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test['target'], preds)
# Out:
# 0.46938775510204084

# %%
# Using Rolling averages to improve precision
grouped_matches = matches.groupby('team')

# %%
group = grouped_matches.get_group('Manchester City')

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# 6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 10 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W  6.0
# 12 2022-10-08  15:00  Premier League  Matchweek 10  Sat  Home      W  4.0
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# 13 2021-10-23  17:30  Premier League   Matchweek 9  Sat  Away      W  4.0
# 15 2021-10-30  15:00  Premier League  Matchweek 10  Sat  Home      L  0.0
# 17 2021-11-06  12:30  Premier League  Matchweek 11  Sat  Away      W  2.0
# 18 2021-11-21  14:00  Premier League  Matchweek 12  Sun  Home      W  3.0
# 20 2021-11-28  14:00  Premier League  Matchweek 13  Sun  Home      W  2.0
# 21 2021-12-01  20:15  Premier League  Matchweek 14  Wed  Away      W  2.0
# 22 2021-12-04  17:30  Premier League  Matchweek 15  Sat  Away      W  3.0
# 24 2021-12-11  12:30  Premier League  Matchweek 16  Sat  Home      W  1.0
# 25 2021-12-14  20:00  Premier League  Matchweek 17  Tue  Home      W  7.0
# 26 2021-12-19  14:15  Premier League  Matchweek 18  Sun  Away      W  4.0
# 27 2021-12-26  15:00  Premier League  Matchweek 19  Sun  Home      W  6.0
# 28 2021-12-29  20:15  Premier League  Matchweek 20  Wed  Away      W  1.0
# 29 2022-01-01  12:30  Premier League  Matchweek 21  Sat  Away      W  2.0
# 31 2022-01-15  12:30  Premier League  Matchweek 22  Sat  Home      W  1.0
# 32 2022-01-22  17:30  Premier League  Matchweek 23  Sat  Away      D  1.0
# 34 2022-02-09  19:45  Premier League  Matchweek 24  Wed  Home      W  2.0
# 35 2022-02-12  17:30  Premier League  Matchweek 25  Sat  Away      W  4.0
# 37 2022-02-19  17:30  Premier League  Matchweek 26  Sat  Home      L  2.0
# 38 2022-02-26  17:30  Premier League  Matchweek 27  Sat  Away      W  1.0
# 40 2022-03-06  16:30  Premier League  Matchweek 28  Sun  Home      W  4.0
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
# 52 2022-04-30  17:30  Premier League  Matchweek 35  Sat  Away      W  4.0
# 54 2022-05-08  16:30  Premier League  Matchweek 36  Sun  Home      W  5.0
# 55 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Away      W  5.0
# 56 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  2.0
# 57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W  3.0
#
#      ga         opponent  ...   fk   pk  pkatt  season             team  \
# 1   0.0         West Ham  ...  1.0  1.0    1.0    2022  Manchester City
# 2   0.0      Bournemouth  ...  0.0  0.0    0.0    2022  Manchester City
# 3   3.0    Newcastle Utd  ...  1.0  0.0    0.0    2022  Manchester City
# 4   2.0   Crystal Palace  ...  0.0  0.0    0.0    2022  Manchester City
# 5   0.0  Nott'ham Forest  ...  0.0  0.0    0.0    2022  Manchester City
# 6   1.0      Aston Villa  ...  1.0  0.0    0.0    2022  Manchester City
# 9   0.0           Wolves  ...  0.0  0.0    0.0    2022  Manchester City
# 10  3.0   Manchester Utd  ...  1.0  0.0    0.0    2022  Manchester City
# 12  0.0      Southampton  ...  0.0  0.0    0.0    2022  Manchester City
# 1   1.0        Tottenham  ...  1.0  0.0    0.0    2021  Manchester City
# 2   0.0     Norwich City  ...  1.0  0.0    0.0    2021  Manchester City
# 3   0.0          Arsenal  ...  0.0  0.0    0.0    2021  Manchester City
# 4   0.0   Leicester City  ...  0.0  0.0    0.0    2021  Manchester City
# 6   0.0      Southampton  ...  1.0  0.0    0.0    2021  Manchester City
# 8   0.0          Chelsea  ...  0.0  0.0    0.0    2021  Manchester City
# 10  2.0        Liverpool  ...  1.0  0.0    0.0    2021  Manchester City
# 11  0.0          Burnley  ...  0.0  0.0    0.0    2021  Manchester City
# 13  1.0         Brighton  ...  1.0  0.0    0.0    2021  Manchester City
# 15  2.0   Crystal Palace  ...  0.0  0.0    0.0    2021  Manchester City
# 17  0.0   Manchester Utd  ...  0.0  0.0    0.0    2021  Manchester City
# 18  0.0          Everton  ...  1.0  0.0    0.0    2021  Manchester City
# 20  1.0         West Ham  ...  0.0  0.0    0.0    2021  Manchester City
# 21  1.0      Aston Villa  ...  1.0  0.0    0.0    2021  Manchester City
# 22  1.0          Watford  ...  0.0  0.0    0.0    2021  Manchester City
# 24  0.0           Wolves  ...  0.0  1.0    1.0    2021  Manchester City
# 25  0.0     Leeds United  ...  2.0  0.0    0.0    2021  Manchester City
# 26  0.0    Newcastle Utd  ...  0.0  0.0    0.0    2021  Manchester City
# 27  3.0   Leicester City  ...  1.0  2.0    2.0    2021  Manchester City
# 28  0.0        Brentford  ...  0.0  0.0    0.0    2021  Manchester City
# 29  1.0          Arsenal  ...  0.0  1.0    1.0    2021  Manchester City
# 31  0.0          Chelsea  ...  1.0  0.0    0.0    2021  Manchester City
# 32  1.0      Southampton  ...  0.0  0.0    0.0    2021  Manchester City
# 34  0.0        Brentford  ...  0.0  1.0    1.0    2021  Manchester City
# 35  0.0     Norwich City  ...  0.0  0.0    1.0    2021  Manchester City
# 37  3.0        Tottenham  ...  0.0  1.0    1.0    2021  Manchester City
# 38  0.0          Everton  ...  0.0  0.0    0.0    2021  Manchester City
# 40  1.0   Manchester Utd  ...  1.0  0.0    0.0    2021  Manchester City
# 42  0.0   Crystal Palace  ...  0.0  0.0    0.0    2021  Manchester City
# 44  0.0          Burnley  ...  0.0  0.0    0.0    2021  Manchester City
# 46  2.0        Liverpool  ...  1.0  0.0    0.0    2021  Manchester City
# 49  0.0         Brighton  ...  0.0  0.0    0.0    2021  Manchester City
# 50  1.0          Watford  ...  0.0  1.0    1.0    2021  Manchester City
# 52  0.0     Leeds United  ...  0.0  0.0    0.0    2021  Manchester City
# 54  0.0    Newcastle Utd  ...  1.0  0.0    0.0    2021  Manchester City
# 55  1.0           Wolves  ...  0.0  0.0    0.0    2021  Manchester City
# 56  2.0         West Ham  ...  2.0  0.0    1.0    2021  Manchester City
# 57  2.0      Aston Villa  ...  1.0  0.0    0.0    2021  Manchester City
#
#    venue_code opp_code hour  day_code  target
# 1           0       21   16         6       1
# 2           1        2   15         5       1
# 3           0       15   16         6       0
# 4           1        7   15         5       1
# 5           1       17   19         2       1
# 6           0        1   17         5       0
# 9           0       22   12         5       1
# 10          1       14   14         6       1
# 12          1       18   15         5       1
# 1           0       19   16         6       0
# 2           1       16   15         5       1
# 3           1        0   12         5       1
# 4           0       11   15         5       1
# 6           1       18   15         5       0
# 8           0        6   12         5       1
# 10          0       12   16         6       0
# 11          1        5   15         5       1
# 13          0        4   17         5       1
# 15          1        7   15         5       0
# 17          0       14   12         5       1
# 18          1        8   14         6       1
# 20          1       21   14         6       1
# 21          0        1   20         2       1
# 22          0       20   17         5       1
# 24          1       22   12         5       1
# 25          1       10   20         1       1
# 26          0       15   14         6       1
# 27          1       11   15         6       1
# 28          0        3   20         2       1
# 29          0        0   12         5       1
# 31          1        6   12         5       1
# 32          0       18   17         5       0
# 34          1        3   19         2       1
# 35          0       16   17         5       1
# 37          1       19   17         5       0
# 38          0        8   17         5       1
# 40          1       14   16         6       1
# 42          0        7   20         0       0
# 44          0        5   15         5       1
# 46          1       12   16         6       0
# 49          1        4   20         2       1
# 50          1       20   15         5       1
# 52          0       10   17         5       1
# 54          1       15   16         6       1
# 55          0       22   20         2       1
# 56          0       21   14         6       0
# 57          1        1   16         6       1
#
# [47 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f'{c}_rolling' for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-f49e376da466> in <module>
# ----> 1 matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     733         with option_context("mode.chained_assignment", None):
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#     737                 # gh-20949
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     749
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#     753         return self._wrap_applied_output(
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     204             # group might be modified
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#     208                 mutated = True
#
# <ipython-input-49-f49e376da466> in <lambda>(x)
# ----> 1 matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))
#
# <ipython-input-46-03f874665a72> in rolling_averages(group, cols, new_cols)
#       1 def rolling_averages(group, cols, new_cols):
#       2     group = group.sort_values('date')
# ----> 3     rolling_stats = group[cols].rolling(3, closed='left').mean()
#       4     group[new_cols] = rolling_stats
#       5     group = group.dropna(subset=new_cols)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in rolling(self, window, min_periods, center, win_type, on, axis, closed)
#   10374                 )
#   10375
# > 10376             return Rolling(
#   10377                 self,
#   10378                 window=window,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\window\rolling.py in __init__(self, obj, window, min_periods, center, win_type, axis, on, closed, **kwargs)
#      92         self.win_freq = None
#      93         self.axis = obj._get_axis_number(axis) if axis is not None else None
# ---> 94         self.validate()
#      95         self._numba_func_cache: Dict[Optional[str], Callable] = dict()
#      96
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\window\rolling.py in validate(self)
#    1863
#    1864         if not self.is_datetimelike and self.closed is not None:
# -> 1865             raise ValueError(
#    1866                 "closed only implemented for datetimelike and offset based windows"
#    1867             )
#
# ValueError: closed only implemented for datetimelike and offset based windows

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga        opponent  ...   fk   pk  pkatt  season          team  \
# 0   0.0  Crystal Palace  ...  1.0  0.0    0.0    2022       Arsenal
# 1   2.0  Leicester City  ...  0.0  0.0    0.0    2022       Arsenal
# 2   0.0     Bournemouth  ...  0.0  0.0    0.0    2022       Arsenal
# 3   1.0          Fulham  ...  1.0  0.0    0.0    2022       Arsenal
# 4   1.0     Aston Villa  ...  1.0  0.0    0.0    2022       Arsenal
# ..  ...             ...  ...  ...  ...    ...     ...           ...
# 38  2.0     Aston Villa  ...  0.0  0.0    0.0    2021  Norwich City
# 39  4.0        West Ham  ...  1.0  0.0    0.0    2021  Norwich City
# 40  3.0  Leicester City  ...  0.0  0.0    0.0    2021  Norwich City
# 41  1.0          Wolves  ...  0.0  0.0    0.0    2021  Norwich City
# 42  5.0       Tottenham  ...  0.0  0.0    0.0    2021  Norwich City
#
#    venue_code opp_code hour  day_code  target
# 0           0        7   20         4       1
# 1           1       11   15         5       1
# 2           0        2   17         5       1
# 3           1        9   17         5       1
# 4           1        1   19         2       1
# ..        ...      ...  ...       ...     ...
# 38          0        1   15         5       0
# 39          1       21   14         6       0
# 40          0       11   19         2       0
# 41          0       22   14         6       0
# 42          1       19   16         6       0
#
# [936 rows x 32 columns]
